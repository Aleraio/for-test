# %%
import numpy as np # linear algebra 
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# stats models: regression fitting
import statsmodels.formula.api as smf
# data visualization
import seaborn as sns

# %%
df = pd.read_csv('sleep75.csv')
df.shape
# Out:
# (706, 34)

# %% [markdown]
# # Задание 2.1.1

# %%
# постройте диаграмму рассеяним sleep vs totwrk с ‘подогнанной’ прямой
sns.regplot(data=df, y='sleep', x='totwrk', ci=None, line_kws={"color": "r"})
# Out:
# <AxesSubplot:xlabel='totwrk', ylabel='sleep'>

# %%
# найти параметры оптимальной прямой sleep на totwrk
# подгонка прямой
fitted_line = smf.ols(formula='sleep~totwrk', data=df).fit()
# коэффициенты с округлением
fitted_line.params.round(2)
# Out:
# Intercept    3586.38
# totwrk         -0.15
# dtype: float64

# %%
# найти параметры оптимальной прямой sleep на totwrk без константы
fitted_line = smf.ols(formula='sleep~totwrk+0', data=df).fit()
fitted_line.params.round(2)
# Out:
# totwrk    1.26
# dtype: float64

# %% [markdown]
# # Задание 2.1.2

# %%
#постройте диаграмму рассеяним sleep vs age с ‘подогнанной’ прямой
sns.regplot(data=df, y='sleep', x='age', ci=None, line_kws={"color": "r"})
# Out:
# <AxesSubplot:xlabel='age', ylabel='sleep'>

# %%
#построим диаграмму рассеяним sleep vs age
sns.scatterplot(data=df, y='sleep', x='age')
# Out:
# <AxesSubplot:xlabel='age', ylabel='sleep'>

# %%
# найти параметры оптимальной прямой sleep на age
# подгонка прямой
fitted_line = smf.ols(formula='sleep~age', data=df).fit()
# коэффициенты с округлением
fitted_line.params.round(2)
# Out:
# Intercept    3128.91
# age             3.54
# dtype: float64

# %%
#найти параметры оптимальной прямой sleep на age без константы
fitted_line = smf.ols(formula='sleep~age+0', data=df).fit()
# коэффициенты с округлением
fitted_line.params.round(2)
# Out:
# age    77.82
# dtype: float64

# %% [markdown]
# # 2.1.3 Пример 3
# 1) постройте диаграмму рассеяним sleep vs totwrk с ‘подогнанной’ параболой
# 2) найти параметры оптимальной параболы sleep на totwrk, totwrk2

# %%
#постройте диаграмму рассеяним sleep vs totwrk с ‘подогнанной’ параболой
sns.regplot(data=df, y='sleep', x='totwrk', ci=None, order=2, line_kws={"color": "C1"})
# Out:
# <AxesSubplot:xlabel='totwrk', ylabel='sleep'>

# %%
#найти параметры оптимальной параболы sleep на totwrk, totwrk2
# подгонка параболы
fitted_pol = smf.ols(formula='sleep~totwrk+I(totwrk**2)', data=df).fit()
# коэффициенты с округлением
fitted_pol.params.round(2)
# Out:
# Intercept         3523.59
# totwrk              -0.07
# I(totwrk ** 2)      -0.00
# dtype: float64

# %% [markdown]
# # 2.1.4 Пример 4
# 1) постройте диаграмму рассеяним sleep vs age с ‘подогнанной’ параболой
# 2) найти параметры оптимальной параболы sleep на age, age2

# %%
#постройте диаграмму рассеяним sleep vs age с ‘подогнанной’ параболой
sns.regplot(data=df, y='sleep', x='age', ci=None, order=2, line_kws={"color": "C1"})
# Out:
# <AxesSubplot:xlabel='age', ylabel='sleep'>

# %%
#найти параметры оптимальной параболы sleep на totwrk, totwrk2
# подгонка параболы
fitted_pol = smf.ols(formula='sleep~age+I(age**2)', data=df).fit()
# коэффициенты с округлением
fitted_pol.params.round(2)
# Out:
# Intercept      3608.03
# age             -21.49
# I(age ** 2)       0.30
# dtype: float64

# %% [markdown]
# # 2.1.5 Пример 5
# Найдите параметры оптимальной плоскости sleep на totwrk, age

# %%
# Найдите параметры оптимальной плоскости sleep на totwrk, age
# подгонка плоскости
fitted_plane = smf.ols(formula='sleep~totwrk+age', data=df).fit()
# коэффициенты с округлением
fitted_plane.params.round(2)
# Out:
# Intercept    3469.20
# totwrk         -0.15
# age             2.92
# dtype: float64

# %% [markdown]
# # 2.2.1 Пример 1
# 1) постройте диаграмму рассеяним output vs capital с ‘подогнанной’ прямой
# 2) найти параметры оптимальной прямой output на capital
# 3) найти параметры оптимальной прямой output на capital без константы
# 4)постройте диаграмму рассеяним log(output) vs log(capital) с ‘подогнанной’ прямой
# 5)найти параметры оптимальной прямой log(output) на log(capital)

# %%
df = pd.read_csv('Labour.csv')
df.shape
# Out:
# (569, 4)

# %%
# постройте диаграмму рассеяним output vs capital с ‘подогнанной’ прямой
sns.regplot(data=df, y='output', x='capital', ci=None, line_kws={"color": "r"})
# Out:
# <AxesSubplot:xlabel='capital', ylabel='output'>

# %%
#найти параметры оптимальной прямой output на capital
# подгонка прямой
fitted_line = smf.ols(formula='output~capital', data=df).fit()
# коэффициенты с округлением
fitted_line.params.round(2)
# Out:
# Intercept    6.19
# capital      0.74
# dtype: float64

# %%
#найти параметры оптимальной прямой output на capital без константы
# подгонка прямой
fitted_line = smf.ols(formula='output~capital+0', data=df).fit()
# коэффициенты с округлением
fitted_line.params.round(2)
# Out:
# capital    0.75
# dtype: float64

# %%
sns.regplot(x=np.log(df['capital']), y=np.log(df['output']), ci=None, line_kws={"color": "r"})
# Out:
# <AxesSubplot:xlabel='capital', ylabel='output'>

# %%
# подгонка прямой
fitted_line = smf.ols(formula='np.log(output)~np.log(capital)', data=df).fit()
# коэффициенты с округлением
fitted_line.params.round(2)
# Out:
# Intercept          1.19
# np.log(capital)    0.56
# dtype: float64

# %%
# найти параметры оптимальной прямой log(output) на log(capital)
# подгонка прямой
fitted_line = smf.ols(formula='np.log(output)~np.log(capital)', data=df).fit()
# коэффициенты с округлением
fitted_line.params.round(2)
# Out:
# Intercept          1.19
# np.log(capital)    0.56
# dtype: float64

# %%
# найти параметры оптимальной прямой log(output) на log(capital) без константы
fitted_line = smf.ols(formula='np.log(output)~np.log(capital)+0', data=df).fit()
# коэффициенты с округлением
fitted_line.params.round(2)
# Out:
# np.log(capital)    0.88
# dtype: float64

# %% [markdown]
# # 2.2.2 Пример 2
# 1) постройте диаграмму рассеяним output vs labour с ‘подогнанной’ прямой
# 2) найти параметры оптимальной прямой output на labour
# 3) найти параметры оптимальной прямой output на labour без константы
# 4) постройте диаграмму рассеяним log(output) vs log(labour) с ‘подогнанной’ прямой
# 5) найти параметры оптимальной прямой log(output) на log(labour)
# 6) найти параметры оптимальной прямой log(output) на log(labour) без константы

# %%
# постройте диаграмму рассеяним log(output) vs log(labour) с ‘подогнанной’ прямой 
sns.regplot(x=np.log(df['output']), y=np.log(df['labour']), ci=None, line_kws={"color": "r"})
# Out:
# <AxesSubplot:xlabel='output', ylabel='labour'>

# %%
# найти параметры оптимальной прямой log(output) на log(labour) 
fitted_line = smf.ols(formula='np.log(output)~np.log(labour)', data=df).fit()
# коэффициенты с округлением
fitted_line.params.round(2)
# Out:
# Intercept        -2.38
# np.log(labour)    0.90
# dtype: float64

# %%
# найти параметры оптимальной прямой log(output) на log(labour) без константы
fitted_line = smf.ols(formula='np.log(output)~np.log(labour)+0', data=df).fit()
# коэффициенты с округлением
fitted_line.params.round(2)
# Out:
# np.log(labour)    0.41
# dtype: float64

# %% [markdown]
# 2.2.4 Пример 4
# 1) постройте диаграмму рассеяним log(output) vs log(labour) с ‘подогнанной’ параболой
# 2) найти параметры оптимальной параболы log(output) vs log(labour), log2(labour)

# %%
# постройте диаграмму рассеяним log(output) vs log(labour) с ‘подогнанной’ параболой 
sns.regplot(x=np.log(df['labour']), y=np.log(df['output']), ci=None, order=2, line_kws={"color": "C1"})
# Out:
# <AxesSubplot:xlabel='labour', ylabel='output'>

# %%
#найти параметры оптимальной параболы log(output) vs log(labour), log2(labour)
# подгонка параболы
fitted_pol = smf.ols(formula='np.log(output)~np.log(labour)+I(np.log(labour)**2)', data=df).fit()
# коэффициенты с округлением
fitted_pol.params.round(2)
# Out:
# Intercept                -1.28
# np.log(labour)            0.37
# I(np.log(labour) ** 2)    0.06
# dtype: float64

# %%
sns.histplot(data=df, x='output')
# Out:
# <AxesSubplot:xlabel='output', ylabel='Count'>
